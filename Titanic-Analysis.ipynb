# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].idxmax
# Out:
# <bound method Series.idxmax of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df[df['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df[df['Cabin'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# filter data in 'Age' and 'Survived' column 
df[['Age', 'Survived']]
# Out:
#       Age  Survived
# 0    22.0         0
# 1    38.0         1
# 2    26.0         1
# 3    35.0         1
# 4    35.0         0
# ..    ...       ...
# 886  27.0         0
# 887  19.0         1
# 888   NaN         0
# 889  26.0         1
# 890  32.0         0
#
# [891 rows x 2 columns]

# %%
#selected age that survived
df_age_survive = df[df['Survived']== 1]

# %%
len(df_age_survive)
# Out:
# 342

# %%
#total rate of survival
(len(df_age_survive) * 100) / 891
# Out:
# 38.38383838383838

# %%
df_age_survive['Age'].unique()
# Out:
# array([38.  , 26.  , 35.  , 27.  , 14.  ,  4.  , 58.  , 55.  ,   nan,
#        34.  , 15.  , 28.  ,  3.  , 19.  , 49.  , 29.  , 21.  ,  5.  ,
#        17.  , 32.  ,  0.83, 30.  , 33.  , 23.  , 32.5 , 12.  , 24.  ,
#        22.  , 16.  , 40.  ,  9.  ,  1.  , 45.  , 44.  , 18.  , 31.  ,
#         8.  , 37.  , 50.  , 25.  , 41.  , 63.  , 42.  ,  0.92, 36.  ,
#         2.  , 60.  , 39.  , 13.  , 52.  , 48.  ,  0.75, 54.  ,  7.  ,
#        62.  , 53.  , 20.  , 80.  , 56.  ,  6.  ,  0.67, 51.  , 43.  ,
#        11.  ,  0.42, 47.  ])

# %%
df_age_survive['Age'].value_counts()
# Out:
# Age
# 24.00    15
# 36.00    11
# 35.00    11
# 27.00    11
# 22.00    11
#          ..
# 55.00     1
# 32.50     1
# 12.00     1
# 0.92      1
# 47.00     1
# Name: count, Length: 65, dtype: int64

# %%
df_age_survive[df_age_survive['Age'].isna()].index
# Out:
# Index([ 17,  19,  28,  31,  32,  36,  47,  55,  65,  82, 107, 109, 128, 166,
#        186, 198, 241, 256, 274, 298, 300, 301, 303, 306, 330, 334, 347, 358,
#        359, 367, 368, 375, 431, 444, 457, 507, 533, 547, 573, 596, 612, 643,
#        653, 669, 692, 697, 709, 727, 740, 828, 839, 849],
#       dtype='int64')

# %%
df_age_survive
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_age_survive.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             52
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          206
# Embarked         2
# dtype: int64

# %%
df_age_survive.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 15           16         1       2
# 17           18         1       2
# 19           20         1       3
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 25           26         1       3
# 28           29         1       3
# 31           32         1       1
# 32           33         1       3
# 36           37         1       3
# 39           40         1       3
# 43           44         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
#the data frame of teenage that survive
df_teen = df_age_survive[df_age_survive['Age'] <= 18]

# %%
df_teen
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 855          856         1       3                Aks, Mrs. Sam (Leah Rosen)
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
age_45_under = df_age_survive[df_age_survive['Age'] <= 45]
df_adult = age_45_under[age_45_under['Age'] > 18]

# %%
len(df_adult)
# Out:
# 182

# %%
age_over = df_age_survive[df_age_survive['Age'] > 45]

# %%
len(age_over)
# Out:
# 38

# %%
age_survive_type = pd.DataFrame([len(df_adult), len(df_teen), len(age_over)])

# %%
pd.DataFrame([len(df_adult), len(df_teen), len(age_over)])
# Out:
#      0
# 0  182
# 1   70
# 2   38

# %%
# Create new data frame for survied by age.

# %%
df_age = pd.DataFrame({'age': ['Adult', 'Teen', 'Elder'], 'age_survived': [182, 70, 38]})
df_age
# Out:
#      age  age_survived
# 0  Adult           182
# 1   Teen            70
# 2  Elder            38

# %%
df_age['rate'] = df_age['age_survived'] * 100 / len(df_age_survive)

# %%
len(df_age_survive)
# Out:
# 342

# %%
df_age
# Out:
#      age  age_survived       rate
# 0  Adult           182  53.216374
# 1   Teen            70  20.467836
# 2  Elder            38  11.111111

# %%
df_age.plot(kind='bar', x='age', y='rate', width=0.5, legend = False)
plt.title('Passengers survived by Age')
plt.xlabel('Age')
plt.ylabel('Age Survived Rate(%)')
plt.show()

# %% [markdown]
# ## 5. Rate of traveling alone

# %%
# filter columns Parch
df_parch = df[df['Parch'] == 0]

# %%
# filter column SibSp from column Parch
df_alone = df_parch[df_parch['SibSp'] == 0]

# %%
df_alone[df_alone['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 875          876         1       3
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#the amount of people that travel alone and survive
total_survive_alone = len(df_alone[df_alone['Survived'] == 1])

# %%
total_survive = len(df[df['Survived'] == 1])

# %%
#the rate of the people did survive
alone_rate = total_survive_alone * 100 / total_survive
print(alone_rate)
# Out:
# 47.66081871345029

# %% [markdown]
# # 6. Gender

# %%
df['Sex'].isna().sum()
# Out:
# 0

# %%
df_male = df[df['Sex'] == 'male']

# %%
df_female = df[df['Sex'] == 'female']

# %%
df_male_survive = df_male[df_male['Survived'] == 1]

# %%
df_female_survive = df_female[df_female['Survived'] == 1]

# %%
total_survive = len(df[df['Survived'] == 1])

# %%
total_survive
# Out:
# 342

# %%
rate_male = len(df_male_survive) * 100 / total_survive

# %%
rate_female =len(df_female_survive) * 100 / total_survive

# %%
len(df_male_survive)
# Out:
# 109

# %%
print(rate_male, rate_female)
# Out:
# 31.871345029239766 68.12865497076024

# %%
len(df_female_survive)
# Out:
# 233

# %%
gender_survive = pd.DataFrame([{'Male':rate_male, 'Female':rate_female}])
gender_survive.head()
# Out:
#         Male     Female
# 0  31.871345  68.128655

# %%
gender_survive
# Out:
#         Male     Female
# 0  31.871345  68.128655

# %%
df_gender_survive = pd.DataFrame({'gender': ['male', 'female'], 'gender_rate': [31.871, 68.128]})
df_gender_survive
# Out:
#    gender  gender_rate
# 0    male       31.871
# 1  female       68.128

# %%
df_gender_survive.plot(kind='bar', x='gender', y='gender_rate', color='skyblue', width=0.5, legend = False)
plt.title('Passengers survived by Gender')
plt.xlabel('Genders')
plt.ylabel('Gender Survived Rate')
plt.show()

# %% [markdown]
# ## 4. Survived by family

# %%
#calculate the row that travel alone
df_family = df.drop(df_alone.index)

# %%
df_family = df_family[df_family['Survived'] == 1]

# %%
df_family
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# ..           ...       ...     ...
# 869          870         1       3
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# calculate the rate of family that survived 
rate_of_family = len(df_family) * 100 / total_survive

# %%
rate_of_family
# Out:
# 52.33918128654971

# %%
survive_index = [100, ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[284], line 1
# ----> 1 df.corr()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...
